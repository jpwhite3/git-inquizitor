# %% [markdown]
# # New Jupyter Notebook

# %%
import inquizitor

repo_path = "/Users/jpwhite/Code/lvlup/aws-serverless-registration-app"
output_file = "git_statistics.json"


analyzer = inquizitor.GitStatisticsAnalyzer(repo_path)
# Out:
# Processing Commits: 100%|██████████| 697/697 [00:11<00:00, 58.42it/s]

# %%
analyzer.stats
# Out:
# {'by_author': {'GitHub (noreply@github.com)': {'commit_count': 20,
#    'insertions': 2481,
#    'deletions': 1202},
#   'JP White (jpwhite3@gmail.com)': {'commit_count': 291,
#    'insertions': 31786,
#    'deletions': 19483},
#   'Erin Perry (georeri@iit.edu)': {'commit_count': 299,
#    'insertions': 11021,
#    'deletions': 9777},
#   'Mike Cornell (mcornell74@gmail.com)': {'commit_count': 77,
#    'insertions': 6684,
#    'deletions': 4348},
#   'Erin Perry (erinperry@Erins-MacBook-Air.local)': {'commit_count': 6,
#    'insertions': 299,
#    'deletions': 187},
#   'JP White (jpwhite3@users.noreply.github.com)': {'commit_count': 4,
#    'insertions': 205,
#    'deletions': 102}},
#  'by_file': {'.devcontainer/devcontainer.json': {'date_introduced': '2022-12-07T21:46:20+00:00',
#    'total_commits': 1,
#    'total_lines': 30,
#    'lines_by_author': {'JP White (jpwhite3@gmail.com)': 30}},
#   '.github/workflows/appCI.yml': {'date_introduced': '2023-06-30T18:21:06-04:00',
# ...
